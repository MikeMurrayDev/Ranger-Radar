# %% [markdown]
# # Data Upload
# ---
#
# **Imports**

# %%
import sshtunnel
import mysql.connector
from mysql.connector import errorcode

import pandas as pd

# %% [markdown]
# **SSH settings**

# %%
sshtunnel.SSH_TIMEOUT = 5.0
sshtunnel.TUNNEL_TIMEOUT = 5.0

# %% [markdown]
# **Table Schema**

# %%
TABLES = {}

TABLES['sightings'] = (
    "CREATE TABLE `sightings` ("
    "  `id` int(11) NOT NULL AUTO_INCREMENT,"
    "  `lat` Decimal(9,6) NOT NULL,"
    "  `long` Decimal(9,6) NOT NULL,"
    "  `timestamp` varchar(30) NOT NULL,"
    "  `species` varchar(50) NOT NULL,"
    "  `pic_url` varchar(500) NOT NULL,"
    "  PRIMARY KEY (`id`)"
    ")")

TABLES['research'] = (
    "CREATE TABLE `research` ("
    "  `id` int(11) NOT NULL AUTO_INCREMENT,"
    "  `lat` Decimal(9,6) NOT NULL,"
    "  `long` Decimal(9,6) NOT NULL,"
    "  `timestamp` varchar(30) NOT NULL,"
    "  `species` varchar(50) NOT NULL,"
    "  `subject_id` varchar(50),"
    "  PRIMARY KEY (`id`)"
    ")")

TABLES['corridors'] = (
    "CREATE TABLE `corridors` ("
    "  `id` int(11) NOT NULL AUTO_INCREMENT,"
    "  `lat` date NOT NULL,"
    "  `long` varchar(14) NOT NULL,"
    "  `vert_spread` varchar(16) NOT NULL,"
    "  `horiz_spread` varchar(16) NOT NULL,"
    "  `pic_url` enum('M','F') NOT NULL,"
    "  PRIMARY KEY (`id`)"
    ")")

# %% [markdown]
# **Helper Functions**

# %%
def create_database(cursor):
    try:
        cursor.execute(
            "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(DB_NAME))
    except mysql.connector.Error as err:
        print("Failed creating database: {}".format(err))
        exit(1)
    
    return True
        
def upload_query_gen(file_name, record):
    return ("INSERT INTO {} VALUES (" + "{}, "*3 + "'{}' ,"*(len(record)-4) + "'{}')").format(file_name, *list(record))

# %% [markdown]
# **SSH Tunnel**

# %%
tunnel =  sshtunnel.SSHTunnelForwarder(
    ('ssh.pythonanywhere.com'),
    ssh_username='rangerradar', 
    ssh_password='fv1s2r112!@',
    remote_bind_address=('rangerradar.mysql.pythonanywhere-services.com', 3306)
)

tunnel.start()

# %% [markdown]
# **MySQL Connection**

# %%
connection = mysql.connector.connect(
    user='rangerradar', 
    password='rrsql12!@',
    host='rangerradar.mysql.pythonanywhere-services.com', 
    port=3306,
    database='rangerradar$sdzoohack',
)
    
cursor = connection.cursor()
DB_NAME = 'sdzoohack'

# %% [markdown]
# **Create Tables Using Schema Dict**

# %%
for table_name in TABLES:
    
    table_description = TABLES[table_name]
    
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    
    else:
        print("done.")
# Out:
# Creating table sightings: done.
# Creating table research: done.
# Creating table corridors: done.

# %% [markdown]
# **Iterate through cleaned CSVs and push to DB**

# %%
for file_name in ['sightings', 'research']:
    
    print(f'Working on {file_name}...')
    
    try:
        df = pd.read_csv(f'../data/{file_name}_to_sql.csv').reset_index()
        # print(df.shape)
    
    except:
        continue

    for i, record in enumerate(df.values):
        
        if i % 500 == 0:
            connection.commit()
            print(f'{(i / df.shape[0]) * 100} percent done')
        
        query = upload_query_gen(file_name, record)
        # print(query)
        
        try:
            cursor.execute(query)
    
        except mysql.connector.Error as err:
            print(err)
            continue
    
    print(f'{file_name} finished.')

print('----------\nDone.')
# Out:
# Working on sightings...
# 0.0 percent done
# 1062 (23000): Duplicate entry '1' for key 'PRIMARY'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 14.068655036578503 percent done
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 28.137310073157007 percent done
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 42.20596510973551 percent done
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 56.274620146314014 percent done
# 70.34327518289251 percent done
# 84.41193021947102 percent done
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 1054 (42S22): Unknown column 'nan' in 'field list'
# 98.48058525604952 percent done
# sightings finished.
# Working on research...
# 0.0 percent done
# 1062 (23000): Duplicate entry '1' for key 'PRIMARY'
# 0.5000600072008641 percent done
# 1.0001200144017282 percent done
# 1.5001800216025925 percent done
# 2.0002400288034563 percent done
# 2.5003000360043206 percent done
# 3.000360043205185 percent done
# 3.5004200504060488 percent done
# 4.000480057606913 percent done
# 4.500540064807777 percent done
# 5.000600072008641 percent done
# 5.5006600792095055 percent done
# 6.00072008641037 percent done
# 6.500780093611233 percent done
# 7.0008401008120975 percent done
# 7.500900108012962 percent done
# 8.000960115213825 percent done
# 8.50102012241469 percent done
# 9.001080129615554 percent done
# 9.501140136816417 percent done
# 10.001200144017282 percent done
# 10.501260151218146 percent done
# 11.001320158419011 percent done
# 11.501380165619874 percent done
# 12.00144017282074 percent done
# 12.501500180021601 percent done
# 13.001560187222466 percent done
# 13.50162019442333 percent done
# 14.001680201624195 percent done
# 14.501740208825058 percent done
# 15.001800216025924 percent done
# 15.501860223226787 percent done
# 16.00192023042765 percent done
# 16.501980237628516 percent done
# 17.00204024482938 percent done
# 17.502100252030246 percent done
# 18.002160259231108 percent done
# 18.50222026643197 percent done
# 19.002280273632834 percent done
# 19.5023402808337 percent done
# 20.002400288034565 percent done
# 20.502460295235426 percent done
# 21.00252030243629 percent done
# 21.502580309637157 percent done
# 22.002640316838022 percent done
# 22.502700324038884 percent done
# 23.00276033123975 percent done
# 23.502820338440614 percent done
# 24.00288034564148 percent done
# 24.50294035284234 percent done
# 25.003000360043202 percent done
# 25.503060367244068 percent done
# 26.003120374444933 percent done
# 26.503180381645798 percent done
# 27.00324038884666 percent done
# 27.503300396047525 percent done
# 28.00336040324839 percent done
# 28.503420410449255 percent done
# 29.003480417650117 percent done
# 29.503540424850982 percent done
# 30.003600432051847 percent done
# 30.503660439252712 percent done
# 31.003720446453574 percent done
# 31.50378045365444 percent done
# 32.0038404608553 percent done
# 32.503900468056166 percent done
# 33.00396047525703 percent done
# 33.504020482457896 percent done
# 34.00408048965876 percent done
# 34.50414049685963 percent done
# 35.00420050406049 percent done
# 35.50426051126136 percent done
# 36.004320518462215 percent done
# 36.50438052566308 percent done
# 37.00444053286394 percent done
# 37.504500540064804 percent done
# 38.00456054726567 percent done
# 38.504620554466534 percent done
# 39.0046805616674 percent done
# 39.504740568868264 percent done
# 40.00480057606913 percent done
# 40.504860583269995 percent done
# 41.00492059047085 percent done
# 41.50498059767172 percent done
# 42.00504060487258 percent done
# 42.50510061207345 percent done
# 43.005160619274314 percent done
# 43.50522062647518 percent done
# 44.005280633676044 percent done
# 44.50534064087691 percent done
# 45.00540064807777 percent done
# 45.50546065527863 percent done
# 46.0055206624795 percent done
# 46.50558066968036 percent done
# 47.00564067688123 percent done
# 47.50570068408209 percent done
# 48.00576069128296 percent done
# 48.505820698483824 percent done
# 49.00588070568468 percent done
# 49.50594071288555 percent done
# 50.006000720086405 percent done
# 50.50606072728727 percent done
# 51.006120734488135 percent done
# 51.506180741689 percent done
# 52.006240748889866 percent done
# 52.50630075609073 percent done
# 53.006360763291596 percent done
# 53.506420770492454 percent done
# 54.00648077769332 percent done
# 54.506540784894185 percent done
# 55.00660079209505 percent done
# 55.506660799295915 percent done
# 56.00672080649678 percent done
# 56.506780813697645 percent done
# 57.00684082089851 percent done
# 57.506900828099376 percent done
# 58.006960835300234 percent done
# 58.5070208425011 percent done
# 59.007080849701964 percent done
# 59.50714085690283 percent done
# 60.007200864103694 percent done
# 60.50726087130456 percent done
# 61.007320878505425 percent done
# 61.50738088570628 percent done
# 62.00744089290715 percent done
# 62.50750090010801 percent done
# 63.00756090730888 percent done
# 63.507620914509744 percent done
# 64.0076809217106 percent done
# 64.50774092891147 percent done
# 65.00780093611233 percent done
# 65.5078609433132 percent done
# 66.00792095051406 percent done
# 66.50798095771493 percent done
# 67.00804096491579 percent done
# 67.50810097211667 percent done
# 68.00816097931752 percent done
# 68.50822098651838 percent done
# 69.00828099371925 percent done
# 69.50834100092011 percent done
# 70.00840100812098 percent done
# 70.50846101532184 percent done
# 71.00852102252271 percent done
# 71.50858102972356 percent done
# 72.00864103692443 percent done
# 72.50870104412529 percent done
# 73.00876105132616 percent done
# 73.50882105852702 percent done
# 74.00888106572788 percent done
# 74.50894107292875 percent done
# 75.00900108012961 percent done
# 75.50906108733048 percent done
# 76.00912109453134 percent done
# 76.50918110173221 percent done
# 77.00924110893307 percent done
# 77.50930111613393 percent done
# 78.0093611233348 percent done
# 78.50942113053566 percent done
# 79.00948113773653 percent done
# 79.50954114493739 percent done
# 80.00960115213826 percent done
# 80.50966115933912 percent done
# 81.00972116653999 percent done
# 81.50978117374085 percent done
# 82.0098411809417 percent done
# 82.50990118814258 percent done
# 83.00996119534344 percent done
# 83.51002120254431 percent done
# 84.01008120974517 percent done
# 84.51014121694604 percent done
# 85.0102012241469 percent done
# 85.51026123134776 percent done
# 86.01032123854863 percent done
# 86.51038124574949 percent done
# 87.01044125295036 percent done
# 87.51050126015122 percent done
# 88.01056126735209 percent done
# 88.51062127455295 percent done
# 89.01068128175382 percent done
# 89.51074128895468 percent done
# 90.01080129615553 percent done
# 90.5108613033564 percent done
# 91.01092131055726 percent done
# 91.51098131775814 percent done
# 92.011041324959 percent done
# 92.51110133215987 percent done
# 93.01116133936073 percent done
# 93.51122134656158 percent done
# 94.01128135376246 percent done
# 94.51134136096331 percent done
# 95.01140136816419 percent done
# 95.51146137536504 percent done
# 96.01152138256592 percent done
# 96.51158138976677 percent done
# 97.01164139696765 percent done
# 97.5117014041685 percent done
# 98.01176141136936 percent done
# 98.51182141857024 percent done
# 99.0118814257711 percent done
# 99.51194143297197 percent done
# research finished.
# ----------
# Done.

# %% [markdown]
# **Close Connections**

# %%
cursor.close()
connection.close()
